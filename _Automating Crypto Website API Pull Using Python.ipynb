# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'25',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '4f509ba1-0f0c-48ec-9c19-aa425e39f093',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-03-12T17:43:07.265Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 9062}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10089, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19315568, 'total_supply': 19315568, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:41:00.000Z', 'quote': {'USD': {'price': 20849.0130571955, 'volume_24h': 20772695790.816044, 'volume_change_24h': -33.4764, 'percent_change_1h': 1.29713275, 'percent_change_24h': 2.51401254, 'percent_change_7d': -7.13113007, 'percent_change_30d': -3.7235727, 'percent_change_60d': 19.93090054, 'percent_change_90d': 22.57530401, 'market_cap': 402710529439.1476, 'market_cap_dominance': 41.7668, 'fully_diluted_market_cap': 437829274201.11, 'tvl': None, 'last_updated': '2023-03-12T17:41:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6569, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:41:00.000Z', 'quote': {'USD': {'price': 1520.7043418899032, 'volume_24h': 8942067837.397678, 'volume_change_24h': -37.9803, 'percent_change_1h': 3.1295071, 'percent_change_24h': 4.65528043, 'percent_change_7d': -3.22299664, 'percent_change_30d': -0.14455448, 'percent_change_60d': 14.46887902, 'percent_change_90d': 21.35166969, 'market_cap': 186094469691.2626, 'market_cap_dominance': 19.3169, 'fully_diluted_market_cap': 186094469691.26, 'tvl': None, 'last_updated': '2023-03-12T17:41:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 49154, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 72116708664.75655, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c13 ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the coulumns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# /Users/belal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
#        id              name symbol                  slug  num_market_pairs  \
# 0       1           Bitcoin    BTC               bitcoin             10089
# 1    1027          Ethereum    ETH              ethereum              6569
# 2     825            Tether   USDT                tether             49154
# 3    1839               BNB    BNB                   bnb              1211
# 4    3408          USD Coin   USDC              usd-coin             10561
# 5      52               XRP    XRP                   xrp               903
# 6    2010           Cardano    ADA               cardano               672
# 7    3890           Polygon  MATIC               polygon               608
# 8      74          Dogecoin   DOGE              dogecoin               656
# 9    4687       Binance USD   BUSD           binance-usd              6411
# 10   5426            Solana    SOL                solana               439
# 11   6636          Polkadot    DOT          polkadot-new               479
# 12   4943               Dai    DAI  multi-collateral-dai              1967
# 13   5994         Shiba Inu   SHIB             shiba-inu               493
# 14   1958              TRON    TRX                  tron               736
# 15      2          Litecoin    LTC              litecoin               887
# 16   5805         Avalanche   AVAX             avalanche               386
# 17   7083           Uniswap    UNI               uniswap               623
# 18   3957      UNUS SED LEO    LEO          unus-sed-leo                24
# 19   1975         Chainlink   LINK             chainlink               995
# 20   3794            Cosmos   ATOM                cosmos               413
# 21   3717   Wrapped Bitcoin   WBTC       wrapped-bitcoin               930
# 22  11419           Toncoin    TON               toncoin                89
# 23    328            Monero    XMR                monero               208
# 24   1321  Ethereum Classic    ETC      ethereum-classic               381
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2019-04-28T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2019-09-20T00:00:00.000Z
# 10  2020-04-10T00:00:00.000Z
# 11  2020-08-19T00:00:00.000Z
# 12  2019-11-22T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
# 15  2013-04-28T00:00:00.000Z
# 16  2020-07-13T00:00:00.000Z
# 17  2020-09-17T00:00:00.000Z
# 18  2019-05-21T00:00:00.000Z
# 19  2017-09-20T00:00:00.000Z
# 20  2019-03-14T00:00:00.000Z
# 21  2019-01-30T00:00:00.000Z
# 22  2021-08-26T13:40:22.000Z
# 23  2014-05-21T00:00:00.000Z
# 24  2016-07-24T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 10  [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 11  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 12  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14                  [media, payments, tron-ecosystem]           NaN
# 15        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 16  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 17  [decentralized-exchange-dex-token, defi, dao, ...  1.000000e+09
# 18  [marketplace, centralized-exchange, discount-t...           NaN
# 19  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 20  [platform, cosmos-ecosystem, content-creation,...           NaN
# 21  [medium-of-exchange, defi, wrapped-tokens, fan...           NaN
# 22                                              [pos]  5.000000e+09
# 23  [mineable, pow, medium-of-exchange, privacy, r...           NaN
# 24  [mineable, pow, ethash, platform, smart-contra...  2.107000e+08
#
#     circulating_supply  total_supply  platform  cmc_rank  \
# 0         1.931557e+07  1.931557e+07       NaN         1
# 1         1.223739e+08  1.223739e+08       NaN         2
# 2         7.211671e+10  7.314177e+10       NaN         3
# 3         1.578927e+08  1.599800e+08       NaN         4
# 4         4.067903e+10  4.067903e+10       NaN         5
# 5         5.095091e+10  9.998911e+10       NaN         6
# 6         3.469518e+10  3.557370e+10       NaN         7
# 7         8.734317e+09  1.000000e+10       NaN         8
# 8         1.326708e+11  1.326708e+11       NaN         9
# 9         8.375924e+09  8.375924e+09       NaN        10
# 10        3.829591e+08  5.393127e+08       NaN        11
# 11        1.165334e+09  1.291757e+09       NaN        12
# 12        6.434955e+09  6.434955e+09       NaN        13
# 13        5.490633e+14  5.897350e+14       NaN        14
# 14        9.128003e+10  9.128015e+10       NaN        15
# 15        7.246695e+07  8.400000e+07       NaN        16
# 16        3.255284e+08  4.215911e+08       NaN        17
# 17        7.622093e+08  1.000000e+09       NaN        18
# 18        9.539541e+08  9.852395e+08       NaN        19
# 19        5.171000e+08  1.000000e+09       NaN        20
# 20        2.863703e+08  0.000000e+00       NaN        21
# 21        1.532640e+05  1.532640e+05       NaN        22
# 22        1.221401e+09  5.047559e+09       NaN        23
# 23        1.825149e+07  1.825149e+07       NaN        24
# 24        1.398672e+08  2.107000e+08       NaN        25
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# 5                                NaN                       NaN        NaN
# 6                                NaN                       NaN        NaN
# 7                                NaN                       NaN        NaN
# 8                                NaN                       NaN        NaN
# 9                                NaN                       NaN        NaN
# 10                               NaN                       NaN        NaN
# 11                      9.048698e+08              5.054042e+09        NaN
# 12                               NaN                       NaN        NaN
# 13                               NaN                       NaN        NaN
# 14                      7.165966e+10              4.344576e+09        NaN
# 15                               NaN                       NaN        NaN
# 16                               NaN                       NaN        NaN
# 17                               NaN                       NaN   1.280589
# 18                               NaN                       NaN        NaN
# 19                               NaN                       NaN        NaN
# 20                               NaN                       NaN        NaN
# 21                               NaN                       NaN        NaN
# 22                      3.414167e+09              7.814061e+09        NaN
# 23                               NaN                       NaN        NaN
# 24                               NaN                       NaN        NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-03-12T17:41:00.000Z     20849.013057          2.077270e+10
# 1   2023-03-12T17:41:00.000Z      1520.704342          8.942068e+09
# 2   2023-03-12T17:41:00.000Z         1.010787          3.790799e+10
# 3   2023-03-12T17:41:00.000Z       280.581879          3.656395e+08
# 4   2023-03-12T17:41:00.000Z         0.966050          1.045950e+10
# 5   2023-03-12T17:41:00.000Z         0.358888          8.360677e+08
# 6   2023-03-12T17:41:00.000Z         0.312526          2.908253e+08
# 7   2023-03-12T17:41:00.000Z         1.104901          5.116528e+08
# 8   2023-03-12T17:41:00.000Z         0.067455          2.525195e+08
# 9   2023-03-12T17:41:00.000Z         1.005943          4.481733e+09
# 10  2023-03-12T17:41:00.000Z        18.574961          4.013615e+08
# 11  2023-03-12T17:41:00.000Z         5.585381          2.064353e+08
# 12  2023-03-12T17:41:00.000Z         0.967619          1.852743e+09
# 13  2023-03-12T17:41:00.000Z         0.000010          1.622902e+08
# 14  2023-03-12T17:41:00.000Z         0.060628          3.049315e+08
# 15  2023-03-12T17:41:00.000Z        70.306020          6.649854e+08
# 16  2023-03-12T17:41:00.000Z        14.821441          1.289831e+08
# 17  2023-03-12T17:41:00.000Z         5.588973          8.760446e+07
# 18  2023-03-12T17:41:00.000Z         3.687596          1.159079e+06
# 19  2023-03-12T17:41:00.000Z         6.277165          2.096036e+08
# 20  2023-03-12T17:41:00.000Z        11.318203          1.243142e+08
# 21  2023-03-12T17:41:00.000Z     20902.003753          2.378464e+08
# 22  2023-03-12T17:41:00.000Z         2.288717          2.192598e+07
# 23  2023-03-12T17:41:00.000Z       147.107818          9.210645e+07
# 24  2023-03-12T17:41:00.000Z        17.450779          1.070792e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -33.4764                     1.297133
# 1                      -37.9803                     3.129507
# 2                      -42.4098                    -0.002016
# 3                      -28.0562                     1.223025
# 4                      -58.6706                     0.691861
# 5                      -22.9955                     1.820003
# 6                      -34.0764                     1.739670
# 7                      -34.1627                     1.945845
# 8                      -43.7986                     1.680573
# 9                      -52.9721                     0.074285
# 10                     -42.8218                     2.858965
# 11                     -34.7624                     2.489985
# 12                     -53.5159                     0.807500
# 13                     -41.8940                     1.561691
# 14                     -27.2282                     1.710818
# 15                     -33.3388                     2.054121
# 16                     -47.6178                     2.541248
# 17                     -37.7755                     1.987872
# 18                      14.1151                     0.623413
# 19                     -36.1215                     1.745842
# 20                     -45.0272                     1.307462
# 21                     -67.4147                     1.430107
# 22                     -23.9781                     0.551631
# 23                       8.7285                     0.699441
# 24                     -38.9118                     1.999211
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       2.514013                    -7.131130
# 1                       4.655280                    -3.222997
# 2                       0.188049                     1.069473
# 3                       2.273151                    -3.609939
# 4                       2.662066                    -3.401584
# 5                      -1.643733                    -3.051050
# 6                       2.046504                    -7.630961
# 7                       7.141696                    -3.220681
# 8                       3.255758                   -10.502010
# 9                       0.579747                     0.543605
# 10                      5.131522                   -12.588176
# 11                      4.087212                    -7.248115
# 12                      1.061892                    -3.205949
# 13                      1.301559                    -7.925835
# 14                      6.118361                   -10.134522
# 15                      1.723758                   -22.412705
# 16                      3.386027                    -9.596469
# 17                      3.428028                   -11.219035
# 18                      6.902134                     9.900285
# 19                      3.134507                    -9.702194
# 20                      4.493117                    -7.246566
# 21                      2.342589                    -6.856840
# 22                      1.862913                    -3.241834
# 23                      4.464459                    -1.183370
# 24                      2.662990                   -12.880420
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -3.723573                     19.930901
# 1                      -0.144554                     14.468879
# 2                       1.054898                      1.079027
# 3                      -8.381450                      1.245897
# 4                      -3.402265                     -3.393889
# 5                      -5.418441                     -3.489572
# 6                     -13.065615                      0.809008
# 7                     -12.464803                     29.461380
# 8                     -16.996828                    -10.626674
# 9                       0.581170                      0.572575
# 10                    -10.448301                     19.840821
# 11                     -9.717633                     15.231340
# 12                     -3.237008                     -3.227770
# 13                    -16.002445                     17.126268
# 14                     -4.253824                     10.302324
# 15                    -23.429749                    -13.304168
# 16                    -17.133192                     18.924666
# 17                    -11.324703                     -0.847506
# 18                      9.953064                      6.071612
# 19                     -9.570269                      3.786260
# 20                    -17.133561                      1.749200
# 21                     -3.285066                     20.368002
# 22                      7.655510                      7.392327
# 23                     -3.418087                     -8.981596
# 24                    -16.872614                    -11.013810
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      22.575304          4.027105e+11
# 1                      21.351670          1.860945e+11
# 2                       1.064955          7.289465e+10
# 3                       1.601307          4.430183e+10
# 4                      -3.399994          3.929798e+10
# 5                      -4.766836          1.828567e+10
# 6                       2.631723          1.084313e+10
# 7                      24.715196          9.650555e+09
# 8                     -23.604069          8.949279e+09
# 9                       0.644079          8.425706e+09
# 10                     41.346014          7.113451e+09
# 11                      8.745303          6.508833e+09
# 12                     -3.203443          6.226587e+09
# 13                     16.390382          5.656599e+09
# 14                     14.849275          5.534118e+09
# 15                     -6.200563          5.094863e+09
# 16                     16.287847          4.824800e+09
# 17                     -4.214666          4.259967e+09
# 18                     -0.918810          3.517798e+09
# 19                     -4.749910          3.245922e+09
# 20                     18.560815          3.241197e+09
# 21                     23.127555          3.203525e+09
# 22                     10.452643          2.795442e+09
# 23                     -2.120740          2.684937e+09
# 24                     -4.830537          2.440791e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          41.7668                        4.378293e+11
# 1                          19.3169                        1.860945e+11
# 2                           7.5602                        7.393076e+10
# 3                           4.5986                        4.488748e+10
# 4                           4.0792                        3.929798e+10
# 5                           1.8981                        3.588879e+10
# 6                           1.1246                        1.406365e+10
# 7                           1.0017                        1.104901e+10
# 8                           0.9282                        8.949279e+09
# 9                           0.8739                        8.425706e+09
# 10                          0.7378                        1.001771e+10
# 11                          0.6751                        7.214957e+09
# 12                          0.6463                        6.226587e+09
# 13                          0.5867                        6.075610e+09
# 14                          0.5740                        5.534125e+09
# 15                          0.5284                        5.905706e+09
# 16                          0.5008                        1.067144e+10
# 17                          0.4422                        5.588973e+09
# 18                          0.3652                        3.633165e+09
# 19                          0.3366                        6.277165e+09
# 20                          0.3364                        0.000000e+00
# 21                          0.3323                        3.203525e+09
# 22                          0.2902                        1.144359e+10
# 23                          0.2785                        2.684937e+09
# 24                          0.2534                        3.676879e+09
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 1             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 2             NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 3             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 4             NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 5             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 6             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 7             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 8             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 9             NaN  2023-03-12T17:41:00.000Z       1839.0           BNB
# 10            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 11            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 12            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 13            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 14            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 15            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 16            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 17   3.326569e+09  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 18            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 19            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 20            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 21            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 22            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 23            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 24            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              BNB           bnb                                    BUSD-BD1
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
# 15             NaN           NaN                                         NaN
# 16             NaN           NaN                                         NaN
# 17             ETH      ethereum  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984
# 18             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 19             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 20             NaN           NaN                                         NaN
# 21             ETH      ethereum  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 22             NaN           NaN                                         NaN
# 23             NaN           NaN                                         NaN
# 24             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-03-12 18:33:53.202041
# 1  2023-03-12 18:33:53.202041
# 2  2023-03-12 18:33:53.202041
# 3  2023-03-12 18:33:53.202041
# 4  2023-03-12 18:33:53.202041
# 5  2023-03-12 18:33:53.202041
# 6  2023-03-12 18:33:53.202041
# 7  2023-03-12 18:33:53.202041
# 8  2023-03-12 18:33:53.202041
# 9  2023-03-12 18:33:53.202041
# 10 2023-03-12 18:33:53.202041
# 11 2023-03-12 18:33:53.202041
# 12 2023-03-12 18:33:53.202041
# 13 2023-03-12 18:33:53.202041
# 14 2023-03-12 18:33:53.202041
# 15 2023-03-12 18:33:53.202041
# 16 2023-03-12 18:33:53.202041
# 17 2023-03-12 18:33:53.202041
# 18 2023-03-12 18:33:53.202041
# 19 2023-03-12 18:33:53.202041
# 20 2023-03-12 18:33:53.202041
# 21 2023-03-12 18:33:53.202041
# 22 2023-03-12 18:33:53.202041
# 23 2023-03-12 18:33:53.202041
# 24 2023-03-12 18:33:53.202041

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'25',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '4f509ba1-0f0c-48ec-9c19-aa425e39f093',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now')
    df_append = pd.DataFrame(df2)
    df = pd.concat([df2,df_append])

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed succesfully')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# {'status': {'timestamp': '2023-03-12T17:52:26.219Z', 'error_code': 0, 'error_message': None, 'elapsed': 16, 'credit_count': 1, 'notice': None, 'total_count': 9062}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10089, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19315568, 'total_supply': 19315568, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:50:00.000Z', 'quote': {'USD': {'price': 20973.867135388387, 'volume_24h': 20986730129.69509, 'volume_change_24h': -33.0216, 'percent_change_1h': 1.76049663, 'percent_change_24h': 2.61751283, 'percent_change_7d': -6.5664698, 'percent_change_30d': -3.23416694, 'percent_change_60d': 20.65492279, 'percent_change_90d': 23.27226541, 'market_cap': 405122156876.55963, 'market_cap_dominance': 41.9274, 'fully_diluted_market_cap': 440451209843.16, 'tvl': None, 'last_updated': '2023-03-12T17:50:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6569, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:50:00.000Z', 'quote': {'USD': {'price': 1527.5116483423603, 'volume_24h': 8991722830.236965, 'volume_change_24h': -38.1187, 'percent_change_1h': 3.33667218, 'percent_change_24h': 4.52237258, 'percent_change_7d': -2.74353699, 'percent_change_30d': 0.288653, 'percent_change_60d': 14.99731501, 'percent_change_90d': 21.82622064, 'market_cap': 186927506100.37918, 'market_cap_dominance': 19.3594, 'fully_diluted_market_cap': 186927506100.38, 'tvl': None, 'last_updated': '2023-03-12T17:50:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 49155, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 72116708664.75655, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c1 ...
# API Runner completed succesfully
# /Users/belal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# {'status': {'timestamp': '2023-03-12T17:53:26.420Z', 'error_code': 0, 'error_message': None, 'elapsed': 16, 'credit_count': 1, 'notice': None, 'total_count': 9062}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10089, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19315568, 'total_supply': 19315568, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:51:00.000Z', 'quote': {'USD': {'price': 20979.03833445771, 'volume_24h': 21003874747.343792, 'volume_change_24h': -32.9573, 'percent_change_1h': 1.7699226, 'percent_change_24h': 2.64247901, 'percent_change_7d': -6.53871168, 'percent_change_30d': -3.20354873, 'percent_change_60d': 20.6558239, 'percent_change_90d': 23.30564979, 'market_cap': 405222041523.82465, 'market_cap_dominance': 41.9377, 'fully_diluted_market_cap': 440559805023.61, 'tvl': None, 'last_updated': '2023-03-12T17:51:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6569, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:51:00.000Z', 'quote': {'USD': {'price': 1527.6082694837228, 'volume_24h': 8994090624.321688, 'volume_change_24h': -38.1079, 'percent_change_1h': 3.33188423, 'percent_change_24h': 4.51714596, 'percent_change_7d': -2.74355423, 'percent_change_30d': 0.29880948, 'percent_change_60d': 14.99069687, 'percent_change_90d': 21.83523497, 'market_cap': 186939330003.00607, 'market_cap_dominance': 19.2894, 'fully_diluted_market_cap': 186939330003.01, 'tvl': None, 'last_updated': '2023-03-12T17:51:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 49155, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 72116708664.75655, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c ...
# API Runner completed succesfully
# /Users/belal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# {'status': {'timestamp': '2023-03-12T17:54:26.683Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 9062}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10089, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19315568, 'total_supply': 19315568, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:52:00.000Z', 'quote': {'USD': {'price': 21004.914589382606, 'volume_24h': 21043857047.99402, 'volume_change_24h': -32.8811, 'percent_change_1h': 1.89820534, 'percent_change_24h': 2.71836768, 'percent_change_7d': -6.41390444, 'percent_change_30d': -3.08488998, 'percent_change_60d': 20.79816349, 'percent_change_90d': 23.43401583, 'market_cap': 405721856085.4118, 'market_cap_dominance': 41.8772, 'fully_diluted_market_cap': 441103206377.03, 'tvl': None, 'last_updated': '2023-03-12T17:52:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6569, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:52:00.000Z', 'quote': {'USD': {'price': 1529.6731180635322, 'volume_24h': 9008597822.328623, 'volume_change_24h': -38.0727, 'percent_change_1h': 3.47529494, 'percent_change_24h': 4.63701968, 'percent_change_7d': -2.58201007, 'percent_change_30d': 0.42439522, 'percent_change_60d': 15.15304319, 'percent_change_90d': 21.96568989, 'market_cap': 187192013506.87167, 'market_cap_dominance': 19.3154, 'fully_diluted_market_cap': 187192013506.87, 'tvl': None, 'last_updated': '2023-03-12T17:52:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 49155, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 72116708664.75655, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597 ...
# API Runner completed succesfully
# /Users/belal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# {'status': {'timestamp': '2023-03-12T17:55:26.874Z', 'error_code': 0, 'error_message': None, 'elapsed': 17, 'credit_count': 1, 'notice': None, 'total_count': 9062}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10089, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19315568, 'total_supply': 19315568, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:53:00.000Z', 'quote': {'USD': {'price': 21007.023616348153, 'volume_24h': 21060381317.62255, 'volume_change_24h': -32.8374, 'percent_change_1h': 1.85845707, 'percent_change_24h': 2.75126104, 'percent_change_7d': -6.4028912, 'percent_change_30d': -3.07545532, 'percent_change_60d': 20.80343038, 'percent_change_90d': 23.44316488, 'market_cap': 405762593139.17865, 'market_cap_dominance': 41.8814, 'fully_diluted_market_cap': 441147495943.31, 'tvl': None, 'last_updated': '2023-03-12T17:53:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6569, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:53:00.000Z', 'quote': {'USD': {'price': 1529.8290068480892, 'volume_24h': 9014219306.937008, 'volume_change_24h': -38.0526, 'percent_change_1h': 3.43286553, 'percent_change_24h': 4.6719403, 'percent_change_7d': -2.56838634, 'percent_change_30d': 0.43795778, 'percent_change_60d': 15.16331969, 'percent_change_90d': 21.9847189, 'market_cap': 187211090220.1379, 'market_cap_dominance': 19.3174, 'fully_diluted_market_cap': 187211090220.14, 'tvl': None, 'last_updated': '2023-03-12T17:53:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 49155, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 72116708664.75655, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c13 ...
# API Runner completed succesfully
# /Users/belal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# {'status': {'timestamp': '2023-03-12T17:56:27.109Z', 'error_code': 0, 'error_message': None, 'elapsed': 16, 'credit_count': 1, 'notice': None, 'total_count': 9062}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10089, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19315568, 'total_supply': 19315568, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:54:00.000Z', 'quote': {'USD': {'price': 20968.131548416328, 'volume_24h': 21072213781.86665, 'volume_change_24h': -32.7911, 'percent_change_1h': 1.6231574, 'percent_change_24h': 2.59667658, 'percent_change_7d': -6.57736477, 'percent_change_30d': -3.27860737, 'percent_change_60d': 20.58214226, 'percent_change_90d': 23.21509613, 'market_cap': 405011370756.38086, 'market_cap_dominance': 41.8038, 'fully_diluted_market_cap': 440330762516.74, 'tvl': None, 'last_updated': '2023-03-12T17:54:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6569, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:54:00.000Z', 'quote': {'USD': {'price': 1528.617552468969, 'volume_24h': 9018624087.843079, 'volume_change_24h': -38.012, 'percent_change_1h': 3.28548101, 'percent_change_24h': 4.60695835, 'percent_change_7d': -2.63455993, 'percent_change_30d': 0.33408594, 'percent_change_60d': 15.06305464, 'percent_change_90d': 21.88329316, 'market_cap': 187062839864.0185, 'market_cap_dominance': 19.3021, 'fully_diluted_market_cap': 187062839864.02, 'tvl': None, 'last_updated': '2023-03-12T17:54:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 49155, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 72116708664.75655, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c13 ...
# API Runner completed succesfully
# /Users/belal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# {'status': {'timestamp': '2023-03-12T17:57:27.318Z', 'error_code': 0, 'error_message': None, 'elapsed': 15, 'credit_count': 1, 'notice': None, 'total_count': 9062}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10089, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19315568, 'total_supply': 19315568, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:55:00.000Z', 'quote': {'USD': {'price': 20977.530225031274, 'volume_24h': 21088438790.475273, 'volume_change_24h': -32.7214, 'percent_change_1h': 1.6274716, 'percent_change_24h': 2.66362555, 'percent_change_7d': -6.52180615, 'percent_change_30d': -3.2824714, 'percent_change_60d': 20.64414431, 'percent_change_90d': 23.28093607, 'market_cap': 405192911533.6469, 'market_cap_dominance': 41.8226, 'fully_diluted_market_cap': 440528134725.66, 'tvl': None, 'last_updated': '2023-03-12T17:55:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6569, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-12T17:55:00.000Z', 'quote': {'USD': {'price': 1530.0500459310667, 'volume_24h': 9035004093.281475, 'volume_change_24h': -37.8778, 'percent_change_1h': 3.29407463, 'percent_change_24h': 4.73386751, 'percent_change_7d': -2.55320718, 'percent_change_30d': 0.38398719, 'percent_change_60d': 15.20139269, 'percent_change_90d': 22.02001475, 'market_cap': 187238139627.30713, 'market_cap_dominance': 19.3202, 'fully_diluted_market_cap': 187238139627.31, 'tvl': None, 'last_updated': '2023-03-12T17:55:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 49155, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 72116708664.75655, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c ...
# API Runner completed succesfully
# /Users/belal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qb/qgffcsnn7sq1nvfnpbhf2lf00000gn/T/ipykernel_6896/1051823300.py in <module>
#       6     api_runner()
#       7     print('API Runner completed succesfully')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#        id              name symbol                  slug  num_market_pairs  \
# 0       1           Bitcoin    BTC               bitcoin             10089
# 1    1027          Ethereum    ETH              ethereum              6569
# 2     825            Tether   USDT                tether             49154
# 3    1839               BNB    BNB                   bnb              1211
# 4    3408          USD Coin   USDC              usd-coin             10561
# 5      52               XRP    XRP                   xrp               903
# 6    2010           Cardano    ADA               cardano               672
# 7    3890           Polygon  MATIC               polygon               608
# 8      74          Dogecoin   DOGE              dogecoin               656
# 9    4687       Binance USD   BUSD           binance-usd              6411
# 10   5426            Solana    SOL                solana               439
# 11   6636          Polkadot    DOT          polkadot-new               479
# 12   4943               Dai    DAI  multi-collateral-dai              1967
# 13   5994         Shiba Inu   SHIB             shiba-inu               493
# 14   1958              TRON    TRX                  tron               736
# 15      2          Litecoin    LTC              litecoin               887
# 16   5805         Avalanche   AVAX             avalanche               386
# 17   7083           Uniswap    UNI               uniswap               623
# 18   3957      UNUS SED LEO    LEO          unus-sed-leo                24
# 19   1975         Chainlink   LINK             chainlink               995
# 20   3794            Cosmos   ATOM                cosmos               413
# 21   3717   Wrapped Bitcoin   WBTC       wrapped-bitcoin               930
# 22  11419           Toncoin    TON               toncoin                89
# 23    328            Monero    XMR                monero               208
# 24   1321  Ethereum Classic    ETC      ethereum-classic               381
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2019-04-28T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2019-09-20T00:00:00.000Z
# 10  2020-04-10T00:00:00.000Z
# 11  2020-08-19T00:00:00.000Z
# 12  2019-11-22T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
# 15  2013-04-28T00:00:00.000Z
# 16  2020-07-13T00:00:00.000Z
# 17  2020-09-17T00:00:00.000Z
# 18  2019-05-21T00:00:00.000Z
# 19  2017-09-20T00:00:00.000Z
# 20  2019-03-14T00:00:00.000Z
# 21  2019-01-30T00:00:00.000Z
# 22  2021-08-26T13:40:22.000Z
# 23  2014-05-21T00:00:00.000Z
# 24  2016-07-24T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 10  [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 11  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 12  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14                  [media, payments, tron-ecosystem]           NaN
# 15        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 16  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 17  [decentralized-exchange-dex-token, defi, dao, ...  1.000000e+09
# 18  [marketplace, centralized-exchange, discount-t...           NaN
# 19  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 20  [platform, cosmos-ecosystem, content-creation,...           NaN
# 21  [medium-of-exchange, defi, wrapped-tokens, fan...           NaN
# 22                                              [pos]  5.000000e+09
# 23  [mineable, pow, medium-of-exchange, privacy, r...           NaN
# 24  [mineable, pow, ethash, platform, smart-contra...  2.107000e+08
#
#     circulating_supply  total_supply  platform  cmc_rank  \
# 0         1.931557e+07  1.931557e+07       NaN         1
# 1         1.223739e+08  1.223739e+08       NaN         2
# 2         7.211671e+10  7.314177e+10       NaN         3
# 3         1.578927e+08  1.599800e+08       NaN         4
# 4         4.067903e+10  4.067903e+10       NaN         5
# 5         5.095091e+10  9.998911e+10       NaN         6
# 6         3.469518e+10  3.557370e+10       NaN         7
# 7         8.734317e+09  1.000000e+10       NaN         8
# 8         1.326708e+11  1.326708e+11       NaN         9
# 9         8.375924e+09  8.375924e+09       NaN        10
# 10        3.829591e+08  5.393127e+08       NaN        11
# 11        1.165334e+09  1.291757e+09       NaN        12
# 12        6.434955e+09  6.434955e+09       NaN        13
# 13        5.490633e+14  5.897350e+14       NaN        14
# 14        9.128003e+10  9.128015e+10       NaN        15
# 15        7.246695e+07  8.400000e+07       NaN        16
# 16        3.255284e+08  4.215911e+08       NaN        17
# 17        7.622093e+08  1.000000e+09       NaN        18
# 18        9.539541e+08  9.852395e+08       NaN        19
# 19        5.171000e+08  1.000000e+09       NaN        20
# 20        2.863703e+08  0.000000e+00       NaN        21
# 21        1.532640e+05  1.532640e+05       NaN        22
# 22        1.221401e+09  5.047559e+09       NaN        23
# 23        1.825149e+07  1.825149e+07       NaN        24
# 24        1.398672e+08  2.107000e+08       NaN        25
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# 5                                NaN                       NaN        NaN
# 6                                NaN                       NaN        NaN
# 7                                NaN                       NaN        NaN
# 8                                NaN                       NaN        NaN
# 9                                NaN                       NaN        NaN
# 10                               NaN                       NaN        NaN
# 11                      9.048698e+08              5.054042e+09        NaN
# 12                               NaN                       NaN        NaN
# 13                               NaN                       NaN        NaN
# 14                      7.165966e+10              4.344576e+09        NaN
# 15                               NaN                       NaN        NaN
# 16                               NaN                       NaN        NaN
# 17                               NaN                       NaN   1.280589
# 18                               NaN                       NaN        NaN
# 19                               NaN                       NaN        NaN
# 20                               NaN                       NaN        NaN
# 21                               NaN                       NaN        NaN
# 22                      3.414167e+09              7.814061e+09        NaN
# 23                               NaN                       NaN        NaN
# 24                               NaN                       NaN        NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-03-12T17:41:00.000Z     20849.013057          2.077270e+10
# 1   2023-03-12T17:41:00.000Z      1520.704342          8.942068e+09
# 2   2023-03-12T17:41:00.000Z         1.010787          3.790799e+10
# 3   2023-03-12T17:41:00.000Z       280.581879          3.656395e+08
# 4   2023-03-12T17:41:00.000Z         0.966050          1.045950e+10
# 5   2023-03-12T17:41:00.000Z         0.358888          8.360677e+08
# 6   2023-03-12T17:41:00.000Z         0.312526          2.908253e+08
# 7   2023-03-12T17:41:00.000Z         1.104901          5.116528e+08
# 8   2023-03-12T17:41:00.000Z         0.067455          2.525195e+08
# 9   2023-03-12T17:41:00.000Z         1.005943          4.481733e+09
# 10  2023-03-12T17:41:00.000Z        18.574961          4.013615e+08
# 11  2023-03-12T17:41:00.000Z         5.585381          2.064353e+08
# 12  2023-03-12T17:41:00.000Z         0.967619          1.852743e+09
# 13  2023-03-12T17:41:00.000Z         0.000010          1.622902e+08
# 14  2023-03-12T17:41:00.000Z         0.060628          3.049315e+08
# 15  2023-03-12T17:41:00.000Z        70.306020          6.649854e+08
# 16  2023-03-12T17:41:00.000Z        14.821441          1.289831e+08
# 17  2023-03-12T17:41:00.000Z         5.588973          8.760446e+07
# 18  2023-03-12T17:41:00.000Z         3.687596          1.159079e+06
# 19  2023-03-12T17:41:00.000Z         6.277165          2.096036e+08
# 20  2023-03-12T17:41:00.000Z        11.318203          1.243142e+08
# 21  2023-03-12T17:41:00.000Z     20902.003753          2.378464e+08
# 22  2023-03-12T17:41:00.000Z         2.288717          2.192598e+07
# 23  2023-03-12T17:41:00.000Z       147.107818          9.210645e+07
# 24  2023-03-12T17:41:00.000Z        17.450779          1.070792e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -33.4764                     1.297133
# 1                      -37.9803                     3.129507
# 2                      -42.4098                    -0.002016
# 3                      -28.0562                     1.223025
# 4                      -58.6706                     0.691861
# 5                      -22.9955                     1.820003
# 6                      -34.0764                     1.739670
# 7                      -34.1627                     1.945845
# 8                      -43.7986                     1.680573
# 9                      -52.9721                     0.074285
# 10                     -42.8218                     2.858965
# 11                     -34.7624                     2.489985
# 12                     -53.5159                     0.807500
# 13                     -41.8940                     1.561691
# 14                     -27.2282                     1.710818
# 15                     -33.3388                     2.054121
# 16                     -47.6178                     2.541248
# 17                     -37.7755                     1.987872
# 18                      14.1151                     0.623413
# 19                     -36.1215                     1.745842
# 20                     -45.0272                     1.307462
# 21                     -67.4147                     1.430107
# 22                     -23.9781                     0.551631
# 23                       8.7285                     0.699441
# 24                     -38.9118                     1.999211
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       2.514013                    -7.131130
# 1                       4.655280                    -3.222997
# 2                       0.188049                     1.069473
# 3                       2.273151                    -3.609939
# 4                       2.662066                    -3.401584
# 5                      -1.643733                    -3.051050
# 6                       2.046504                    -7.630961
# 7                       7.141696                    -3.220681
# 8                       3.255758                   -10.502010
# 9                       0.579747                     0.543605
# 10                      5.131522                   -12.588176
# 11                      4.087212                    -7.248115
# 12                      1.061892                    -3.205949
# 13                      1.301559                    -7.925835
# 14                      6.118361                   -10.134522
# 15                      1.723758                   -22.412705
# 16                      3.386027                    -9.596469
# 17                      3.428028                   -11.219035
# 18                      6.902134                     9.900285
# 19                      3.134507                    -9.702194
# 20                      4.493117                    -7.246566
# 21                      2.342589                    -6.856840
# 22                      1.862913                    -3.241834
# 23                      4.464459                    -1.183370
# 24                      2.662990                   -12.880420
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -3.723573                     19.930901
# 1                      -0.144554                     14.468879
# 2                       1.054898                      1.079027
# 3                      -8.381450                      1.245897
# 4                      -3.402265                     -3.393889
# 5                      -5.418441                     -3.489572
# 6                     -13.065615                      0.809008
# 7                     -12.464803                     29.461380
# 8                     -16.996828                    -10.626674
# 9                       0.581170                      0.572575
# 10                    -10.448301                     19.840821
# 11                     -9.717633                     15.231340
# 12                     -3.237008                     -3.227770
# 13                    -16.002445                     17.126268
# 14                     -4.253824                     10.302324
# 15                    -23.429749                    -13.304168
# 16                    -17.133192                     18.924666
# 17                    -11.324703                     -0.847506
# 18                      9.953064                      6.071612
# 19                     -9.570269                      3.786260
# 20                    -17.133561                      1.749200
# 21                     -3.285066                     20.368002
# 22                      7.655510                      7.392327
# 23                     -3.418087                     -8.981596
# 24                    -16.872614                    -11.013810
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      22.575304          4.027105e+11
# 1                      21.351670          1.860945e+11
# 2                       1.064955          7.289465e+10
# 3                       1.601307          4.430183e+10
# 4                      -3.399994          3.929798e+10
# 5                      -4.766836          1.828567e+10
# 6                       2.631723          1.084313e+10
# 7                      24.715196          9.650555e+09
# 8                     -23.604069          8.949279e+09
# 9                       0.644079          8.425706e+09
# 10                     41.346014          7.113451e+09
# 11                      8.745303          6.508833e+09
# 12                     -3.203443          6.226587e+09
# 13                     16.390382          5.656599e+09
# 14                     14.849275          5.534118e+09
# 15                     -6.200563          5.094863e+09
# 16                     16.287847          4.824800e+09
# 17                     -4.214666          4.259967e+09
# 18                     -0.918810          3.517798e+09
# 19                     -4.749910          3.245922e+09
# 20                     18.560815          3.241197e+09
# 21                     23.127555          3.203525e+09
# 22                     10.452643          2.795442e+09
# 23                     -2.120740          2.684937e+09
# 24                     -4.830537          2.440791e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          41.7668                        4.378293e+11
# 1                          19.3169                        1.860945e+11
# 2                           7.5602                        7.393076e+10
# 3                           4.5986                        4.488748e+10
# 4                           4.0792                        3.929798e+10
# 5                           1.8981                        3.588879e+10
# 6                           1.1246                        1.406365e+10
# 7                           1.0017                        1.104901e+10
# 8                           0.9282                        8.949279e+09
# 9                           0.8739                        8.425706e+09
# 10                          0.7378                        1.001771e+10
# 11                          0.6751                        7.214957e+09
# 12                          0.6463                        6.226587e+09
# 13                          0.5867                        6.075610e+09
# 14                          0.5740                        5.534125e+09
# 15                          0.5284                        5.905706e+09
# 16                          0.5008                        1.067144e+10
# 17                          0.4422                        5.588973e+09
# 18                          0.3652                        3.633165e+09
# 19                          0.3366                        6.277165e+09
# 20                          0.3364                        0.000000e+00
# 21                          0.3323                        3.203525e+09
# 22                          0.2902                        1.144359e+10
# 23                          0.2785                        2.684937e+09
# 24                          0.2534                        3.676879e+09
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 1             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 2             NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 3             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 4             NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 5             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 6             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 7             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 8             NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 9             NaN  2023-03-12T17:41:00.000Z       1839.0           BNB
# 10            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 11            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 12            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 13            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 14            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 15            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 16            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 17   3.326569e+09  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 18            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 19            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 20            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 21            NaN  2023-03-12T17:41:00.000Z       1027.0      Ethereum
# 22            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 23            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
# 24            NaN  2023-03-12T17:41:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              BNB           bnb                                    BUSD-BD1
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
# 15             NaN           NaN                                         NaN
# 16             NaN           NaN                                         NaN
# 17             ETH      ethereum  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984
# 18             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 19             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 20             NaN           NaN                                         NaN
# 21             ETH      ethereum  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 22             NaN           NaN                                         NaN
# 23             NaN           NaN                                         NaN
# 24             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-03-12 18:33:53.202041
# 1  2023-03-12 18:33:53.202041
# 2  2023-03-12 18:33:53.202041
# 3  2023-03-12 18:33:53.202041
# 4  2023-03-12 18:33:53.202041
# 5  2023-03-12 18:33:53.202041
# 6  2023-03-12 18:33:53.202041
# 7  2023-03-12 18:33:53.202041
# 8  2023-03-12 18:33:53.202041
# 9  2023-03-12 18:33:53.202041
# 10 2023-03-12 18:33:53.202041
# 11 2023-03-12 18:33:53.202041
# 12 2023-03-12 18:33:53.202041
# 13 2023-03-12 18:33:53.202041
# 14 2023-03-12 18:33:53.202041
# 15 2023-03-12 18:33:53.202041
# 16 2023-03-12 18:33:53.202041
# 17 2023-03-12 18:33:53.202041
# 18 2023-03-12 18:33:53.202041
# 19 2023-03-12 18:33:53.202041
# 20 2023-03-12 18:33:53.202041
# 21 2023-03-12 18:33:53.202041
# 22 2023-03-12 18:33:53.202041
# 23 2023-03-12 18:33:53.202041
# 24 2023-03-12 18:33:53.202041

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                   quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                              1.297133                      2.514013
# Ethereum                             3.129507                      4.655280
# Tether                              -0.002016                      0.188049
# BNB                                  1.223025                      2.273151
# USD Coin                             0.691861                      2.662066
# XRP                                  1.820003                     -1.643733
# Cardano                              1.739670                      2.046504
# Polygon                              1.945845                      7.141696
# Dogecoin                             1.680573                      3.255758
# Binance USD                          0.074285                      0.579747
# Solana                               2.858965                      5.131522
# Polkadot                             2.489985                      4.087212
# Dai                                  0.807500                      1.061892
# Shiba Inu                            1.561691                      1.301559
# TRON                                 1.710818                      6.118361
# Litecoin                             2.054121                      1.723758
# Avalanche                            2.541248                      3.386027
# Uniswap                              1.987872                      3.428028
# UNUS SED LEO                         0.623413                      6.902134
# Chainlink                            1.745842                      3.134507
# Cosmos                               1.307462                      4.493117
# Wrapped Bitcoin                      1.430107                      2.342589
# Toncoin                              0.551631                      1.862913
# Monero                               0.699441                      4.464459
# Ethereum Classic                     1.999211                      2.662990
#
#                   quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                             -7.131130                     -3.723573
# Ethereum                            -3.222997                     -0.144554
# Tether                               1.069473                      1.054898
# BNB                                 -3.609939                     -8.381450
# USD Coin                            -3.401584                     -3.402265
# XRP                                 -3.051050                     -5.418441
# Cardano                             -7.630961                    -13.065615
# Polygon                             -3.220681                    -12.464803
# Dogecoin                           -10.502010                    -16.996828
# Binance USD                          0.543605                      0.581170
# Solana                             -12.588176                    -10.448301
# Polkadot                            -7.248115                     -9.717633
# Dai                                 -3.205949                     -3.237008
# Shiba Inu                           -7.925835                    -16.002445
# TRON                               -10.134522                     -4.253824
# Litecoin                           -22.412705                    -23.429749
# Avalanche                           -9.596469                    -17.133192
# Uniswap                            -11.219035                    -11.324703
# UNUS SED LEO                         9.900285                      9.953064
# Chainlink                           -9.702194                     -9.570269
# Cosmos                              -7.246566                    -17.133561
# Wrapped Bitcoin                     -6.856840                     -3.285066
# Toncoin                             -3.241834                      7.655510
# Monero                              -1.183370                     -3.418087
# Ethereum Classic                   -12.880420                    -16.872614
#
#                   quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                              19.930901                     22.575304
# Ethereum                             14.468879                     21.351670
# Tether                                1.079027                      1.064955
# BNB                                   1.245897                      1.601307
# USD Coin                             -3.393889                     -3.399994
# XRP                                  -3.489572                     -4.766836
# Cardano                               0.809008                      2.631723
# Polygon                              29.461380                     24.715196
# Dogecoin                            -10.626674                    -23.604069
# Binance USD                           0.572575                      0.644079
# Solana                               19.840821                     41.346014
# Polkadot                             15.231340                      8.745303
# Dai                                  -3.227770                     -3.203443
# Shiba Inu                            17.126268                     16.390382
# TRON                                 10.302324                     14.849275
# Litecoin                            -13.304168                     -6.200563
# Avalanche                            18.924666                     16.287847
# Uniswap                              -0.847506                     -4.214666
# UNUS SED LEO                          6.071612                     -0.918810
# Chainlink                             3.786260                     -4.749910
# Cosmos                                1.749200                     18.560815
# Wrapped Bitcoin                      20.368002                     23.127555
# Toncoin                               7.392327                     10.452643
# Monero                               -8.981596                     -2.120740
# Ethereum Classic                    -11.013810                     -4.830537

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin           quote.USD.percent_change_1h      1.297133
#                   quote.USD.percent_change_24h     2.514013
#                   quote.USD.percent_change_7d     -7.131130
#                   quote.USD.percent_change_30d    -3.723573
#                   quote.USD.percent_change_60d    19.930901
#                   quote.USD.percent_change_90d    22.575304
# Ethereum          quote.USD.percent_change_1h      3.129507
#                   quote.USD.percent_change_24h     4.655280
#                   quote.USD.percent_change_7d     -3.222997
#                   quote.USD.percent_change_30d    -0.144554
#                   quote.USD.percent_change_60d    14.468879
#                   quote.USD.percent_change_90d    21.351670
# Tether            quote.USD.percent_change_1h     -0.002016
#                   quote.USD.percent_change_24h     0.188049
#                   quote.USD.percent_change_7d      1.069473
#                   quote.USD.percent_change_30d     1.054898
#                   quote.USD.percent_change_60d     1.079027
#                   quote.USD.percent_change_90d     1.064955
# BNB               quote.USD.percent_change_1h      1.223025
#                   quote.USD.percent_change_24h     2.273151
#                   quote.USD.percent_change_7d     -3.609939
#                   quote.USD.percent_change_30d    -8.381450
#                   quote.USD.percent_change_60d     1.245897
#                   quote.USD.percent_change_90d     1.601307
# USD Coin          quote.USD.percent_change_1h      0.691861
#                   quote.USD.percent_change_24h     2.662066
#                   quote.USD.percent_change_7d     -3.401584
#                   quote.USD.percent_change_30d    -3.402265
#                   quote.USD.percent_change_60d    -3.393889
#                   quote.USD.percent_change_90d    -3.399994
# XRP               quote.USD.percent_change_1h      1.820003
#                   quote.USD.percent_change_24h    -1.643733
#                   quote.USD.percent_change_7d     -3.051050
#                   quote.USD.percent_change_30d    -5.418441
#                   quote.USD.percent_change_60d    -3.489572
#                   quote.USD.percent_change_90d    -4.766836
# Cardano           quote.USD.percent_change_1h      1.739670
#                   quote.USD.percent_change_24h     2.046504
#                   quote.USD.percent_change_7d     -7.630961
#                   quote.USD.percent_change_30d   -13.065615
#                   quote.USD.percent_change_60d     0.809008
#                   quote.USD.percent_change_90d     2.631723
# Polygon           quote.USD.percent_change_1h      1.945845
#                   quote.USD.percent_change_24h     7.141696
#                   quote.USD.percent_change_7d     -3.220681
#                   quote.USD.percent_change_30d   -12.464803
#                   quote.USD.percent_change_60d    29.461380
#                   quote.USD.percent_change_90d    24.715196
# Dogecoin          quote.USD.percent_change_1h      1.680573
#                   quote.USD.percent_change_24h     3.255758
#                   quote.USD.percent_change_7d    -10.502010
#                   quote.USD.percent_change_30d   -16.996828
#                   quote.USD.percent_change_60d   -10.626674
#                   quote.USD.percent_change_90d   -23.604069
# Binance USD       quote.USD.percent_change_1h      0.074285
#                   quote.USD.percent_change_24h     0.579747
#                   quote.USD.percent_change_7d      0.543605
#                   quote.USD.percent_change_30d     0.581170
#                   quote.USD.percent_change_60d     0.572575
#                   quote.USD.percent_change_90d     0.644079
# Solana            quote.USD.percent_change_1h      2.858965
#                   quote.USD.percent_change_24h     5.131522
#                   quote.USD.percent_change_7d    -12.588176
#                   quote.USD.percent_change_30d   -10.448301
#                   quote.USD.percent_change_60d    19.840821
#                   quote.USD.percent_change_90d    41.346014
# Polkadot          quote.USD.percent_change_1h      2.489985
#                   quote.USD.percent_change_24h     4.087212
#                   quote.USD.percent_change_7d     -7.248115
#                   quote.USD.percent_change_30d    -9.717633
#                   quote.USD.percent_change_60d    15.231340
#                   quote.USD.percent_change_90d     8.745303
# Dai               quote.USD.percent_change_1h      0.807500
#                   quote.USD.percent_change_24h     1.061892
#                   quote.USD.percent_change_7d     -3.205949
#                   quote.USD.percent_change_30d    -3.237008
#                   quote.USD.percent_change_60d    -3.227770
#                   quote.USD.percent_change_90d    -3.203443
# Shiba Inu         quote.USD.percent_change_1h      1.561691
#                   quote.USD.percent_change_24h     1.301559
#                   quote.USD.percent_change_7d     -7.925835
#                   quote.USD.percent_change_30d   -16.002445
#                   quote.USD.percent_change_60d    17.126268
#                   quote.USD.percent_change_90d    16.390382
# TRON              quote.USD.percent_change_1h      1.710818
#                   quote.USD.percent_change_24h     6.118361
#                   quote.USD.percent_change_7d    -10.134522
#                   quote.USD.percent_change_30d    -4.253824
#                   quote.USD.percent_change_60d    10.302324
#                   quote.USD.percent_change_90d    14.849275
# Litecoin          quote.USD.percent_change_1h      2.054121
#                   quote.USD.percent_change_24h     1.723758
#                   quote.USD.percent_change_7d    -22.412705
#                   quote.USD.percent_change_30d   -23.429749
#                   quote.USD.percent_change_60d   -13.304168
#                   quote.USD.percent_change_90d    -6.200563
# Avalanche         quote.USD.percent_change_1h      2.541248
#                   quote.USD.percent_change_24h     3.386027
#                   quote.USD.percent_change_7d     -9.596469
#                   quote.USD.percent_change_30d   -17.133192
#                   quote.USD.percent_change_60d    18.924666
#                   quote.USD.percent_change_90d    16.287847
# Uniswap           quote.USD.percent_change_1h      1.987872
#                   quote.USD.percent_change_24h     3.428028
#                   quote.USD.percent_change_7d    -11.219035
#                   quote.USD.percent_change_30d   -11.324703
#                   quote.USD.percent_change_60d    -0.847506
#                   quote.USD.percent_change_90d    -4.214666
# UNUS SED LEO      quote.USD.percent_change_1h      0.623413
#                   quote.USD.percent_change_24h     6.902134
#                   quote.USD.percent_change_7d      9.900285
#                   quote.USD.percent_change_30d     9.953064
#                   quote.USD.percent_change_60d     6.071612
#                   quote.USD.percent_change_90d    -0.918810
# Chainlink         quote.USD.percent_change_1h      1.745842
#                   quote.USD.percent_change_24h     3.134507
#                   quote.USD.percent_change_7d     -9.702194
#                   quote.USD.percent_change_30d    -9.570269
#                   quote.USD.percent_change_60d     3.786260
#                   quote.USD.percent_change_90d    -4.749910
# Cosmos            quote.USD.percent_change_1h      1.307462
#                   quote.USD.percent_change_24h     4.493117
#                   quote.USD.percent_change_7d     -7.246566
#                   quote.USD.percent_change_30d   -17.133561
#                   quote.USD.percent_change_60d     1.749200
#                   quote.USD.percent_change_90d    18.560815
# Wrapped Bitcoin   quote.USD.percent_change_1h      1.430107
#                   quote.USD.percent_change_24h     2.342589
#                   quote.USD.percent_change_7d     -6.856840
#                   quote.USD.percent_change_30d    -3.285066
#                   quote.USD.percent_change_60d    20.368002
#                   quote.USD.percent_change_90d    23.127555
# Toncoin           quote.USD.percent_change_1h      0.551631
#                   quote.USD.percent_change_24h     1.862913
#                   quote.USD.percent_change_7d     -3.241834
#                   quote.USD.percent_change_30d     7.655510
#                   quote.USD.percent_change_60d     7.392327
#                   quote.USD.percent_change_90d    10.452643
# Monero            quote.USD.percent_change_1h      0.699441
#                   quote.USD.percent_change_24h     4.464459
#                   quote.USD.percent_change_7d     -1.183370
#                   quote.USD.percent_change_30d    -3.418087
#                   quote.USD.percent_change_60d    -8.981596
#                   quote.USD.percent_change_90d    -2.120740
# Ethereum Classic  quote.USD.percent_change_1h      1.999211
#                   quote.USD.percent_change_24h     2.662990
#                   quote.USD.percent_change_7d    -12.880420
#                   quote.USD.percent_change_30d   -16.872614
#                   quote.USD.percent_change_60d   -11.013810
#                   quote.USD.percent_change_90d    -4.830537
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                                   values
# name
# Bitcoin          quote.USD.percent_change_1h    1.297133
#                  quote.USD.percent_change_24h   2.514013
#                  quote.USD.percent_change_7d   -7.131130
#                  quote.USD.percent_change_30d  -3.723573
#                  quote.USD.percent_change_60d  19.930901
#                  quote.USD.percent_change_90d  22.575304
# Ethereum         quote.USD.percent_change_1h    3.129507
#                  quote.USD.percent_change_24h   4.655280
#                  quote.USD.percent_change_7d   -3.222997
#                  quote.USD.percent_change_30d  -0.144554
#                  quote.USD.percent_change_60d  14.468879
#                  quote.USD.percent_change_90d  21.351670
# Tether           quote.USD.percent_change_1h   -0.002016
#                  quote.USD.percent_change_24h   0.188049
#                  quote.USD.percent_change_7d    1.069473
#                  quote.USD.percent_change_30d   1.054898
#                  quote.USD.percent_change_60d   1.079027
#                  quote.USD.percent_change_90d   1.064955
# BNB              quote.USD.percent_change_1h    1.223025
#                  quote.USD.percent_change_24h   2.273151
#                  quote.USD.percent_change_7d   -3.609939
#                  quote.USD.percent_change_30d  -8.381450
#                  quote.USD.percent_change_60d   1.245897
#                  quote.USD.percent_change_90d   1.601307
# USD Coin         quote.USD.percent_change_1h    0.691861
#                  quote.USD.percent_change_24h   2.662066
#                  quote.USD.percent_change_7d   -3.401584
#                  quote.USD.percent_change_30d  -3.402265
#                  quote.USD.percent_change_60d  -3.393889
#                  quote.USD.percent_change_90d  -3.399994
# XRP              quote.USD.percent_change_1h    1.820003
#                  quote.USD.percent_change_24h  -1.643733
#                  quote.USD.percent_change_7d   -3.051050
#                  quote.USD.percent_change_30d  -5.418441
#                  quote.USD.percent_change_60d  -3.489572
#                  quote.USD.percent_change_90d  -4.766836
# Cardano          quote.USD.percent_change_1h    1.739670
#                  quote.USD.percent_change_24h   2.046504
#                  quote.USD.percent_change_7d   -7.630961
#                  quote.USD.percent_change_30d -13.065615
#                  quote.USD.percent_change_60d   0.809008
#                  quote.USD.percent_change_90d   2.631723
# Polygon          quote.USD.percent_change_1h    1.945845
#                  quote.USD.percent_change_24h   7.141696
#                  quote.USD.percent_change_7d   -3.220681
#                  quote.USD.percent_change_30d -12.464803
#                  quote.USD.percent_change_60d  29.461380
#                  quote.USD.percent_change_90d  24.715196
# Dogecoin         quote.USD.percent_change_1h    1.680573
#                  quote.USD.percent_change_24h   3.255758
#                  quote.USD.percent_change_7d  -10.502010
#                  quote.USD.percent_change_30d -16.996828
#                  quote.USD.percent_change_60d -10.626674
#                  quote.USD.percent_change_90d -23.604069
# Binance USD      quote.USD.percent_change_1h    0.074285
#                  quote.USD.percent_change_24h   0.579747
#                  quote.USD.percent_change_7d    0.543605
#                  quote.USD.percent_change_30d   0.581170
#                  quote.USD.percent_change_60d   0.572575
#                  quote.USD.percent_change_90d   0.644079
# Solana           quote.USD.percent_change_1h    2.858965
#                  quote.USD.percent_change_24h   5.131522
#                  quote.USD.percent_change_7d  -12.588176
#                  quote.USD.percent_change_30d -10.448301
#                  quote.USD.percent_change_60d  19.840821
#                  quote.USD.percent_change_90d  41.346014
# Polkadot         quote.USD.percent_change_1h    2.489985
#                  quote.USD.percent_change_24h   4.087212
#                  quote.USD.percent_change_7d   -7.248115
#                  quote.USD.percent_change_30d  -9.717633
#                  quote.USD.percent_change_60d  15.231340
#                  quote.USD.percent_change_90d   8.745303
# Dai              quote.USD.percent_change_1h    0.807500
#                  quote.USD.percent_change_24h   1.061892
#                  quote.USD.percent_change_7d   -3.205949
#                  quote.USD.percent_change_30d  -3.237008
#                  quote.USD.percent_change_60d  -3.227770
#                  quote.USD.percent_change_90d  -3.203443
# Shiba Inu        quote.USD.percent_change_1h    1.561691
#                  quote.USD.percent_change_24h   1.301559
#                  quote.USD.percent_change_7d   -7.925835
#                  quote.USD.percent_change_30d -16.002445
#                  quote.USD.percent_change_60d  17.126268
#                  quote.USD.percent_change_90d  16.390382
# TRON             quote.USD.percent_change_1h    1.710818
#                  quote.USD.percent_change_24h   6.118361
#                  quote.USD.percent_change_7d  -10.134522
#                  quote.USD.percent_change_30d  -4.253824
#                  quote.USD.percent_change_60d  10.302324
#                  quote.USD.percent_change_90d  14.849275
# Litecoin         quote.USD.percent_change_1h    2.054121
#                  quote.USD.percent_change_24h   1.723758
#                  quote.USD.percent_change_7d  -22.412705
#                  quote.USD.percent_change_30d -23.429749
#                  quote.USD.percent_change_60d -13.304168
#                  quote.USD.percent_change_90d  -6.200563
# Avalanche        quote.USD.percent_change_1h    2.541248
#                  quote.USD.percent_change_24h   3.386027
#                  quote.USD.percent_change_7d   -9.596469
#                  quote.USD.percent_change_30d -17.133192
#                  quote.USD.percent_change_60d  18.924666
#                  quote.USD.percent_change_90d  16.287847
# Uniswap          quote.USD.percent_change_1h    1.987872
#                  quote.USD.percent_change_24h   3.428028
#                  quote.USD.percent_change_7d  -11.219035
#                  quote.USD.percent_change_30d -11.324703
#                  quote.USD.percent_change_60d  -0.847506
#                  quote.USD.percent_change_90d  -4.214666
# UNUS SED LEO     quote.USD.percent_change_1h    0.623413
#                  quote.USD.percent_change_24h   6.902134
#                  quote.USD.percent_change_7d    9.900285
#                  quote.USD.percent_change_30d   9.953064
#                  quote.USD.percent_change_60d   6.071612
#                  quote.USD.percent_change_90d  -0.918810
# Chainlink        quote.USD.percent_change_1h    1.745842
#                  quote.USD.percent_change_24h   3.134507
#                  quote.USD.percent_change_7d   -9.702194
#                  quote.USD.percent_change_30d  -9.570269
#                  quote.USD.percent_change_60d   3.786260
#                  quote.USD.percent_change_90d  -4.749910
# Cosmos           quote.USD.percent_change_1h    1.307462
#                  quote.USD.percent_change_24h   4.493117
#                  quote.USD.percent_change_7d   -7.246566
#                  quote.USD.percent_change_30d -17.133561
#                  quote.USD.percent_change_60d   1.749200
#                  quote.USD.percent_change_90d  18.560815
# Wrapped Bitcoin  quote.USD.percent_change_1h    1.430107
#                  quote.USD.percent_change_24h   2.342589
#                  quote.USD.percent_change_7d   -6.856840
#                  quote.USD.percent_change_30d  -3.285066
#                  quote.USD.percent_change_60d  20.368002
#                  quote.USD.percent_change_90d  23.127555
# Toncoin          quote.USD.percent_change_1h    0.551631
#                  quote.USD.percent_change_24h   1.862913
#                  quote.USD.percent_change_7d   -3.241834
#                  quote.USD.percent_change_30d   7.655510
#                  quote.USD.percent_change_60d   7.392327
#                  quote.USD.percent_change_90d  10.452643
# Monero           quote.USD.percent_change_1h    0.699441
#                  quote.USD.percent_change_24h   4.464459
#                  quote.USD.percent_change_7d   -1.183370
#                  quote.USD.percent_change_30d  -3.418087
#                  quote.USD.percent_change_60d  -8.981596
#                  quote.USD.percent_change_90d  -2.120740
# Ethereum Classic quote.USD.percent_change_1h    1.999211
#                  quote.USD.percent_change_24h   2.662990
#                  quote.USD.percent_change_7d  -12.880420
#                  quote.USD.percent_change_30d -16.872614
#                  quote.USD.percent_change_60d -11.013810
#                  quote.USD.percent_change_90d  -4.830537

# %%
df5.count()
# Out:
# values    150
# dtype: int64

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6
# Out:
#                  name                       level_1     values
# 0             Bitcoin   quote.USD.percent_change_1h   1.297133
# 1             Bitcoin  quote.USD.percent_change_24h   2.514013
# 2             Bitcoin   quote.USD.percent_change_7d  -7.131130
# 3             Bitcoin  quote.USD.percent_change_30d  -3.723573
# 4             Bitcoin  quote.USD.percent_change_60d  19.930901
# 5             Bitcoin  quote.USD.percent_change_90d  22.575304
# 6            Ethereum   quote.USD.percent_change_1h   3.129507
# 7            Ethereum  quote.USD.percent_change_24h   4.655280
# 8            Ethereum   quote.USD.percent_change_7d  -3.222997
# 9            Ethereum  quote.USD.percent_change_30d  -0.144554
# 10           Ethereum  quote.USD.percent_change_60d  14.468879
# 11           Ethereum  quote.USD.percent_change_90d  21.351670
# 12             Tether   quote.USD.percent_change_1h  -0.002016
# 13             Tether  quote.USD.percent_change_24h   0.188049
# 14             Tether   quote.USD.percent_change_7d   1.069473
# 15             Tether  quote.USD.percent_change_30d   1.054898
# 16             Tether  quote.USD.percent_change_60d   1.079027
# 17             Tether  quote.USD.percent_change_90d   1.064955
# 18                BNB   quote.USD.percent_change_1h   1.223025
# 19                BNB  quote.USD.percent_change_24h   2.273151
# 20                BNB   quote.USD.percent_change_7d  -3.609939
# 21                BNB  quote.USD.percent_change_30d  -8.381450
# 22                BNB  quote.USD.percent_change_60d   1.245897
# 23                BNB  quote.USD.percent_change_90d   1.601307
# 24           USD Coin   quote.USD.percent_change_1h   0.691861
# 25           USD Coin  quote.USD.percent_change_24h   2.662066
# 26           USD Coin   quote.USD.percent_change_7d  -3.401584
# 27           USD Coin  quote.USD.percent_change_30d  -3.402265
# 28           USD Coin  quote.USD.percent_change_60d  -3.393889
# 29           USD Coin  quote.USD.percent_change_90d  -3.399994
# 30                XRP   quote.USD.percent_change_1h   1.820003
# 31                XRP  quote.USD.percent_change_24h  -1.643733
# 32                XRP   quote.USD.percent_change_7d  -3.051050
# 33                XRP  quote.USD.percent_change_30d  -5.418441
# 34                XRP  quote.USD.percent_change_60d  -3.489572
# 35                XRP  quote.USD.percent_change_90d  -4.766836
# 36            Cardano   quote.USD.percent_change_1h   1.739670
# 37            Cardano  quote.USD.percent_change_24h   2.046504
# 38            Cardano   quote.USD.percent_change_7d  -7.630961
# 39            Cardano  quote.USD.percent_change_30d -13.065615
# 40            Cardano  quote.USD.percent_change_60d   0.809008
# 41            Cardano  quote.USD.percent_change_90d   2.631723
# 42            Polygon   quote.USD.percent_change_1h   1.945845
# 43            Polygon  quote.USD.percent_change_24h   7.141696
# 44            Polygon   quote.USD.percent_change_7d  -3.220681
# 45            Polygon  quote.USD.percent_change_30d -12.464803
# 46            Polygon  quote.USD.percent_change_60d  29.461380
# 47            Polygon  quote.USD.percent_change_90d  24.715196
# 48           Dogecoin   quote.USD.percent_change_1h   1.680573
# 49           Dogecoin  quote.USD.percent_change_24h   3.255758
# 50           Dogecoin   quote.USD.percent_change_7d -10.502010
# 51           Dogecoin  quote.USD.percent_change_30d -16.996828
# 52           Dogecoin  quote.USD.percent_change_60d -10.626674
# 53           Dogecoin  quote.USD.percent_change_90d -23.604069
# 54        Binance USD   quote.USD.percent_change_1h   0.074285
# 55        Binance USD  quote.USD.percent_change_24h   0.579747
# 56        Binance USD   quote.USD.percent_change_7d   0.543605
# 57        Binance USD  quote.USD.percent_change_30d   0.581170
# 58        Binance USD  quote.USD.percent_change_60d   0.572575
# 59        Binance USD  quote.USD.percent_change_90d   0.644079
# 60             Solana   quote.USD.percent_change_1h   2.858965
# 61             Solana  quote.USD.percent_change_24h   5.131522
# 62             Solana   quote.USD.percent_change_7d -12.588176
# 63             Solana  quote.USD.percent_change_30d -10.448301
# 64             Solana  quote.USD.percent_change_60d  19.840821
# 65             Solana  quote.USD.percent_change_90d  41.346014
# 66           Polkadot   quote.USD.percent_change_1h   2.489985
# 67           Polkadot  quote.USD.percent_change_24h   4.087212
# 68           Polkadot   quote.USD.percent_change_7d  -7.248115
# 69           Polkadot  quote.USD.percent_change_30d  -9.717633
# 70           Polkadot  quote.USD.percent_change_60d  15.231340
# 71           Polkadot  quote.USD.percent_change_90d   8.745303
# 72                Dai   quote.USD.percent_change_1h   0.807500
# 73                Dai  quote.USD.percent_change_24h   1.061892
# 74                Dai   quote.USD.percent_change_7d  -3.205949
# 75                Dai  quote.USD.percent_change_30d  -3.237008
# 76                Dai  quote.USD.percent_change_60d  -3.227770
# 77                Dai  quote.USD.percent_change_90d  -3.203443
# 78          Shiba Inu   quote.USD.percent_change_1h   1.561691
# 79          Shiba Inu  quote.USD.percent_change_24h   1.301559
# 80          Shiba Inu   quote.USD.percent_change_7d  -7.925835
# 81          Shiba Inu  quote.USD.percent_change_30d -16.002445
# 82          Shiba Inu  quote.USD.percent_change_60d  17.126268
# 83          Shiba Inu  quote.USD.percent_change_90d  16.390382
# 84               TRON   quote.USD.percent_change_1h   1.710818
# 85               TRON  quote.USD.percent_change_24h   6.118361
# 86               TRON   quote.USD.percent_change_7d -10.134522
# 87               TRON  quote.USD.percent_change_30d  -4.253824
# 88               TRON  quote.USD.percent_change_60d  10.302324
# 89               TRON  quote.USD.percent_change_90d  14.849275
# 90           Litecoin   quote.USD.percent_change_1h   2.054121
# 91           Litecoin  quote.USD.percent_change_24h   1.723758
# 92           Litecoin   quote.USD.percent_change_7d -22.412705
# 93           Litecoin  quote.USD.percent_change_30d -23.429749
# 94           Litecoin  quote.USD.percent_change_60d -13.304168
# 95           Litecoin  quote.USD.percent_change_90d  -6.200563
# 96          Avalanche   quote.USD.percent_change_1h   2.541248
# 97          Avalanche  quote.USD.percent_change_24h   3.386027
# 98          Avalanche   quote.USD.percent_change_7d  -9.596469
# 99          Avalanche  quote.USD.percent_change_30d -17.133192
# 100         Avalanche  quote.USD.percent_change_60d  18.924666
# 101         Avalanche  quote.USD.percent_change_90d  16.287847
# 102           Uniswap   quote.USD.percent_change_1h   1.987872
# 103           Uniswap  quote.USD.percent_change_24h   3.428028
# 104           Uniswap   quote.USD.percent_change_7d -11.219035
# 105           Uniswap  quote.USD.percent_change_30d -11.324703
# 106           Uniswap  quote.USD.percent_change_60d  -0.847506
# 107           Uniswap  quote.USD.percent_change_90d  -4.214666
# 108      UNUS SED LEO   quote.USD.percent_change_1h   0.623413
# 109      UNUS SED LEO  quote.USD.percent_change_24h   6.902134
# 110      UNUS SED LEO   quote.USD.percent_change_7d   9.900285
# 111      UNUS SED LEO  quote.USD.percent_change_30d   9.953064
# 112      UNUS SED LEO  quote.USD.percent_change_60d   6.071612
# 113      UNUS SED LEO  quote.USD.percent_change_90d  -0.918810
# 114         Chainlink   quote.USD.percent_change_1h   1.745842
# 115         Chainlink  quote.USD.percent_change_24h   3.134507
# 116         Chainlink   quote.USD.percent_change_7d  -9.702194
# 117         Chainlink  quote.USD.percent_change_30d  -9.570269
# 118         Chainlink  quote.USD.percent_change_60d   3.786260
# 119         Chainlink  quote.USD.percent_change_90d  -4.749910
# 120            Cosmos   quote.USD.percent_change_1h   1.307462
# 121            Cosmos  quote.USD.percent_change_24h   4.493117
# 122            Cosmos   quote.USD.percent_change_7d  -7.246566
# 123            Cosmos  quote.USD.percent_change_30d -17.133561
# 124            Cosmos  quote.USD.percent_change_60d   1.749200
# 125            Cosmos  quote.USD.percent_change_90d  18.560815
# 126   Wrapped Bitcoin   quote.USD.percent_change_1h   1.430107
# 127   Wrapped Bitcoin  quote.USD.percent_change_24h   2.342589
# 128   Wrapped Bitcoin   quote.USD.percent_change_7d  -6.856840
# 129   Wrapped Bitcoin  quote.USD.percent_change_30d  -3.285066
# 130   Wrapped Bitcoin  quote.USD.percent_change_60d  20.368002
# 131   Wrapped Bitcoin  quote.USD.percent_change_90d  23.127555
# 132           Toncoin   quote.USD.percent_change_1h   0.551631
# 133           Toncoin  quote.USD.percent_change_24h   1.862913
# 134           Toncoin   quote.USD.percent_change_7d  -3.241834
# 135           Toncoin  quote.USD.percent_change_30d   7.655510
# 136           Toncoin  quote.USD.percent_change_60d   7.392327
# 137           Toncoin  quote.USD.percent_change_90d  10.452643
# 138            Monero   quote.USD.percent_change_1h   0.699441
# 139            Monero  quote.USD.percent_change_24h   4.464459
# 140            Monero   quote.USD.percent_change_7d  -1.183370
# 141            Monero  quote.USD.percent_change_30d  -3.418087
# 142            Monero  quote.USD.percent_change_60d  -8.981596
# 143            Monero  quote.USD.percent_change_90d  -2.120740
# 144  Ethereum Classic   quote.USD.percent_change_1h   1.999211
# 145  Ethereum Classic  quote.USD.percent_change_24h   2.662990
# 146  Ethereum Classic   quote.USD.percent_change_7d -12.880420
# 147  Ethereum Classic  quote.USD.percent_change_30d -16.872614
# 148  Ethereum Classic  quote.USD.percent_change_60d -11.013810
# 149  Ethereum Classic  quote.USD.percent_change_90d  -4.830537

# %%
df7 = df6.rename(columns={'level_1' : 'percent_change'})
df7
# Out:
#                  name                percent_change     values
# 0             Bitcoin   quote.USD.percent_change_1h   1.297133
# 1             Bitcoin  quote.USD.percent_change_24h   2.514013
# 2             Bitcoin   quote.USD.percent_change_7d  -7.131130
# 3             Bitcoin  quote.USD.percent_change_30d  -3.723573
# 4             Bitcoin  quote.USD.percent_change_60d  19.930901
# 5             Bitcoin  quote.USD.percent_change_90d  22.575304
# 6            Ethereum   quote.USD.percent_change_1h   3.129507
# 7            Ethereum  quote.USD.percent_change_24h   4.655280
# 8            Ethereum   quote.USD.percent_change_7d  -3.222997
# 9            Ethereum  quote.USD.percent_change_30d  -0.144554
# 10           Ethereum  quote.USD.percent_change_60d  14.468879
# 11           Ethereum  quote.USD.percent_change_90d  21.351670
# 12             Tether   quote.USD.percent_change_1h  -0.002016
# 13             Tether  quote.USD.percent_change_24h   0.188049
# 14             Tether   quote.USD.percent_change_7d   1.069473
# 15             Tether  quote.USD.percent_change_30d   1.054898
# 16             Tether  quote.USD.percent_change_60d   1.079027
# 17             Tether  quote.USD.percent_change_90d   1.064955
# 18                BNB   quote.USD.percent_change_1h   1.223025
# 19                BNB  quote.USD.percent_change_24h   2.273151
# 20                BNB   quote.USD.percent_change_7d  -3.609939
# 21                BNB  quote.USD.percent_change_30d  -8.381450
# 22                BNB  quote.USD.percent_change_60d   1.245897
# 23                BNB  quote.USD.percent_change_90d   1.601307
# 24           USD Coin   quote.USD.percent_change_1h   0.691861
# 25           USD Coin  quote.USD.percent_change_24h   2.662066
# 26           USD Coin   quote.USD.percent_change_7d  -3.401584
# 27           USD Coin  quote.USD.percent_change_30d  -3.402265
# 28           USD Coin  quote.USD.percent_change_60d  -3.393889
# 29           USD Coin  quote.USD.percent_change_90d  -3.399994
# 30                XRP   quote.USD.percent_change_1h   1.820003
# 31                XRP  quote.USD.percent_change_24h  -1.643733
# 32                XRP   quote.USD.percent_change_7d  -3.051050
# 33                XRP  quote.USD.percent_change_30d  -5.418441
# 34                XRP  quote.USD.percent_change_60d  -3.489572
# 35                XRP  quote.USD.percent_change_90d  -4.766836
# 36            Cardano   quote.USD.percent_change_1h   1.739670
# 37            Cardano  quote.USD.percent_change_24h   2.046504
# 38            Cardano   quote.USD.percent_change_7d  -7.630961
# 39            Cardano  quote.USD.percent_change_30d -13.065615
# 40            Cardano  quote.USD.percent_change_60d   0.809008
# 41            Cardano  quote.USD.percent_change_90d   2.631723
# 42            Polygon   quote.USD.percent_change_1h   1.945845
# 43            Polygon  quote.USD.percent_change_24h   7.141696
# 44            Polygon   quote.USD.percent_change_7d  -3.220681
# 45            Polygon  quote.USD.percent_change_30d -12.464803
# 46            Polygon  quote.USD.percent_change_60d  29.461380
# 47            Polygon  quote.USD.percent_change_90d  24.715196
# 48           Dogecoin   quote.USD.percent_change_1h   1.680573
# 49           Dogecoin  quote.USD.percent_change_24h   3.255758
# 50           Dogecoin   quote.USD.percent_change_7d -10.502010
# 51           Dogecoin  quote.USD.percent_change_30d -16.996828
# 52           Dogecoin  quote.USD.percent_change_60d -10.626674
# 53           Dogecoin  quote.USD.percent_change_90d -23.604069
# 54        Binance USD   quote.USD.percent_change_1h   0.074285
# 55        Binance USD  quote.USD.percent_change_24h   0.579747
# 56        Binance USD   quote.USD.percent_change_7d   0.543605
# 57        Binance USD  quote.USD.percent_change_30d   0.581170
# 58        Binance USD  quote.USD.percent_change_60d   0.572575
# 59        Binance USD  quote.USD.percent_change_90d   0.644079
# 60             Solana   quote.USD.percent_change_1h   2.858965
# 61             Solana  quote.USD.percent_change_24h   5.131522
# 62             Solana   quote.USD.percent_change_7d -12.588176
# 63             Solana  quote.USD.percent_change_30d -10.448301
# 64             Solana  quote.USD.percent_change_60d  19.840821
# 65             Solana  quote.USD.percent_change_90d  41.346014
# 66           Polkadot   quote.USD.percent_change_1h   2.489985
# 67           Polkadot  quote.USD.percent_change_24h   4.087212
# 68           Polkadot   quote.USD.percent_change_7d  -7.248115
# 69           Polkadot  quote.USD.percent_change_30d  -9.717633
# 70           Polkadot  quote.USD.percent_change_60d  15.231340
# 71           Polkadot  quote.USD.percent_change_90d   8.745303
# 72                Dai   quote.USD.percent_change_1h   0.807500
# 73                Dai  quote.USD.percent_change_24h   1.061892
# 74                Dai   quote.USD.percent_change_7d  -3.205949
# 75                Dai  quote.USD.percent_change_30d  -3.237008
# 76                Dai  quote.USD.percent_change_60d  -3.227770
# 77                Dai  quote.USD.percent_change_90d  -3.203443
# 78          Shiba Inu   quote.USD.percent_change_1h   1.561691
# 79          Shiba Inu  quote.USD.percent_change_24h   1.301559
# 80          Shiba Inu   quote.USD.percent_change_7d  -7.925835
# 81          Shiba Inu  quote.USD.percent_change_30d -16.002445
# 82          Shiba Inu  quote.USD.percent_change_60d  17.126268
# 83          Shiba Inu  quote.USD.percent_change_90d  16.390382
# 84               TRON   quote.USD.percent_change_1h   1.710818
# 85               TRON  quote.USD.percent_change_24h   6.118361
# 86               TRON   quote.USD.percent_change_7d -10.134522
# 87               TRON  quote.USD.percent_change_30d  -4.253824
# 88               TRON  quote.USD.percent_change_60d  10.302324
# 89               TRON  quote.USD.percent_change_90d  14.849275
# 90           Litecoin   quote.USD.percent_change_1h   2.054121
# 91           Litecoin  quote.USD.percent_change_24h   1.723758
# 92           Litecoin   quote.USD.percent_change_7d -22.412705
# 93           Litecoin  quote.USD.percent_change_30d -23.429749
# 94           Litecoin  quote.USD.percent_change_60d -13.304168
# 95           Litecoin  quote.USD.percent_change_90d  -6.200563
# 96          Avalanche   quote.USD.percent_change_1h   2.541248
# 97          Avalanche  quote.USD.percent_change_24h   3.386027
# 98          Avalanche   quote.USD.percent_change_7d  -9.596469
# 99          Avalanche  quote.USD.percent_change_30d -17.133192
# 100         Avalanche  quote.USD.percent_change_60d  18.924666
# 101         Avalanche  quote.USD.percent_change_90d  16.287847
# 102           Uniswap   quote.USD.percent_change_1h   1.987872
# 103           Uniswap  quote.USD.percent_change_24h   3.428028
# 104           Uniswap   quote.USD.percent_change_7d -11.219035
# 105           Uniswap  quote.USD.percent_change_30d -11.324703
# 106           Uniswap  quote.USD.percent_change_60d  -0.847506
# 107           Uniswap  quote.USD.percent_change_90d  -4.214666
# 108      UNUS SED LEO   quote.USD.percent_change_1h   0.623413
# 109      UNUS SED LEO  quote.USD.percent_change_24h   6.902134
# 110      UNUS SED LEO   quote.USD.percent_change_7d   9.900285
# 111      UNUS SED LEO  quote.USD.percent_change_30d   9.953064
# 112      UNUS SED LEO  quote.USD.percent_change_60d   6.071612
# 113      UNUS SED LEO  quote.USD.percent_change_90d  -0.918810
# 114         Chainlink   quote.USD.percent_change_1h   1.745842
# 115         Chainlink  quote.USD.percent_change_24h   3.134507
# 116         Chainlink   quote.USD.percent_change_7d  -9.702194
# 117         Chainlink  quote.USD.percent_change_30d  -9.570269
# 118         Chainlink  quote.USD.percent_change_60d   3.786260
# 119         Chainlink  quote.USD.percent_change_90d  -4.749910
# 120            Cosmos   quote.USD.percent_change_1h   1.307462
# 121            Cosmos  quote.USD.percent_change_24h   4.493117
# 122            Cosmos   quote.USD.percent_change_7d  -7.246566
# 123            Cosmos  quote.USD.percent_change_30d -17.133561
# 124            Cosmos  quote.USD.percent_change_60d   1.749200
# 125            Cosmos  quote.USD.percent_change_90d  18.560815
# 126   Wrapped Bitcoin   quote.USD.percent_change_1h   1.430107
# 127   Wrapped Bitcoin  quote.USD.percent_change_24h   2.342589
# 128   Wrapped Bitcoin   quote.USD.percent_change_7d  -6.856840
# 129   Wrapped Bitcoin  quote.USD.percent_change_30d  -3.285066
# 130   Wrapped Bitcoin  quote.USD.percent_change_60d  20.368002
# 131   Wrapped Bitcoin  quote.USD.percent_change_90d  23.127555
# 132           Toncoin   quote.USD.percent_change_1h   0.551631
# 133           Toncoin  quote.USD.percent_change_24h   1.862913
# 134           Toncoin   quote.USD.percent_change_7d  -3.241834
# 135           Toncoin  quote.USD.percent_change_30d   7.655510
# 136           Toncoin  quote.USD.percent_change_60d   7.392327
# 137           Toncoin  quote.USD.percent_change_90d  10.452643
# 138            Monero   quote.USD.percent_change_1h   0.699441
# 139            Monero  quote.USD.percent_change_24h   4.464459
# 140            Monero   quote.USD.percent_change_7d  -1.183370
# 141            Monero  quote.USD.percent_change_30d  -3.418087
# 142            Monero  quote.USD.percent_change_60d  -8.981596
# 143            Monero  quote.USD.percent_change_90d  -2.120740
# 144  Ethereum Classic   quote.USD.percent_change_1h   1.999211
# 145  Ethereum Classic  quote.USD.percent_change_24h   2.662990
# 146  Ethereum Classic   quote.USD.percent_change_7d -12.880420
# 147  Ethereum Classic  quote.USD.percent_change_30d -16.872614
# 148  Ethereum Classic  quote.USD.percent_change_60d -11.013810
# 149  Ethereum Classic  quote.USD.percent_change_90d  -4.830537

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
type(df7)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
